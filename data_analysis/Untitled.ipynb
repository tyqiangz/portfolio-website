# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot

# %%
# Define the instruments to download. We would like to see Apple, Microsoft and the S&P500 index.
tickers = ['AAPL', 'MSFT', '^GSPC']

# We would like all available data from 01/01/2000 until 12/31/2016.
start_date = datetime.today() - timedelta(weeks=52*5)
end_date = datetime.today()

# User pandas_reader.data.DataReader to load the desired data. As simple as that.
panel_data = data.DataReader(name='AAPL', 
                             data_source='yahoo', 
                             start=start_date, 
                             end=end_date)

# %%
panel_data
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2016-09-23   28.697500   27.887501   28.605000   28.177500  209924800.0
# 2016-09-26   28.347500   27.887501   27.910000   28.219999  119477600.0
# 2016-09-27   28.295000   28.084999   28.250000   28.272499   98429600.0
# 2016-09-28   28.660000   28.357500   28.422501   28.487499  118564400.0
# 2016-09-29   28.450001   27.950001   28.290001   28.045000  143548000.0
# ...                ...         ...         ...         ...          ...
# 2021-09-10  155.479996  148.699997  155.000000  148.970001  140646400.0
# 2021-09-13  151.419998  148.750000  150.630005  149.550003  102404300.0
# 2021-09-14  151.070007  146.910004  150.350006  148.119995  109296300.0
# 2021-09-15  149.440002  146.369995  148.559998  149.029999   83281300.0
# 2021-09-16  148.970001  147.220001  148.440002  148.789993   67969100.0
#
#              Adj Close
# Date
# 2016-09-23   26.426001
# 2016-09-26   26.465858
# ...

# %%
def plot(columns, start_date, end_date):

# %%
panel_data.xs("High", axis=1)["2021-08-18"]
# Out:
# 150.72000122070312

# %%
fig, ax = plt.subplots(figsize=(15,8))
ax.plot(panel_data.xs(["High", "Low", "Open", "Close", "Adj Close"], axis=1))
plt.show()
